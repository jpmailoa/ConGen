# %%
import os, argparse
from build_nnfps import main as build_nnfps_main
import numpy as np
import pandas as pds
import pickle, math
from preprocessing import data_preparation, _char_set, get_property, canonocalize
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
import SSVAE
import torch

# %% [markdown]
# # Molecule fingerprint regeneration for transfer learning, if necessary

# %%
# training datafiles to use, pick the combination as you like
csv_files = ['./data/paper_MP_IE_EA.csv',
             './data/paper_MP_clean_canonize_cut.csv',
             './data/paper_ZINC_310k.csv',
             './data/paper_clean_viscosity.csv',
             './data/paper_pubchem_fluorocarbon.csv'] 
# 'data/paper_clean_DC.csv' is skipped for now because it has many wrong & unphysical labels because of NLP

out_pkl = 'data/smiles2nn.pkl'
if os.path.isfile(out_pkl):
    os.system('rm '+out_pkl)

first = True
for csv_file in csv_files:
    args = argparse.Namespace()
    args.csv_file = csv_file
    if first:
        args.input_vocab_file = ''
        args.output_vocab_file = out_pkl
        args.fp_check = False
        # build_nnfps_main(args)
        first = False
    else:
        args.input_vocab_file = out_pkl
        args.output_vocab_file = out_pkl
        args.fp_check = False
        # build_nnfps_main(args)

# %% [markdown]
# # Prepare Combination of Dirty Data for Training SSVAE Model

# %%
# are we doing pre-training version? if yes, change pretrain to True
pretrain = False
pretrain_pkl = 'data/smiles2nn.pkl'

# we will try train generative model with these training data files
if 'csv_files' in locals():
    data_uri = csv_files
else:
    data_uri = ['./data/paper_MP_IE_EA.csv',
                './data/paper_MP_clean_canonize_cut.csv',
                './data/paper_ZINC_310k.csv',
                './data/paper_clean_viscosity.csv',
                './data/paper_pubchem_fluorocarbon.csv'] 

# first check how many data points we have in the training data
tmp_smiles = {}
for csv_in in data_uri:
    data = pds.read_csv( csv_in )
    for i in range(len(data['SMILES'])):
        tmp_smiles[ canonocalize(data['SMILES'][i]) ] = True

# define training, validation, and test set division
ntotal = len(tmp_smiles)
ntrn = math.floor( 0.9 * ntotal )
ntst = ntotal - ntrn
frac_val = 0.05
del data, tmp_smiles

# data preparation
if pretrain:
    data, scaler_Y = data_preparation(data_uri, ntrn, ntst,
                                      frac_val = frac_val,
                                      pretrain_uri = pretrain_pkl)
else:
    data, scaler_Y = data_preparation(data_uri, ntrn, ntst,
                                      frac_val = frac_val)

# tag for dumping intermediate models
dt = '221122121322'
model_dir = 'models/'+dt
tmp_model_tag = model_dir+'/'    
scaler_Y_pkl = 'preprocessed_scaler_Y.pkl'
scaler_Y = pickle.load(open(tmp_model_tag+scaler_Y_pkl,'rb'))

print('::: Data preparation completed')
# Out:
# ::: Data preparation completed

# %% [markdown]
# # Load Previously Trained Model, if Needed

# %%
# pre-defined parameters
beta=10000.
char_set = _char_set()
dim_z = 100
dim_h = 250
n_hidden = 3
batch_size = 100

# tag for dumping intermediate models
save_uri = tmp_model_tag+'model_final.pth.tar'

# Instantiate the model
model = SSVAE.TorchModel(sample_data = data, dim_z = dim_z, dim_h = dim_h,
                         n_hidden = n_hidden, batch_size = batch_size, beta = float(beta), char_set = char_set,
                         tmp_model_tag = tmp_model_tag)
dev = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
model.initialize(torch.Tensor(data['trnY']), torch.Tensor(data['trnMask']), dev)
model.load_state_dict( torch.load(save_uri)['state_dict'] )
model.eval()
# Out:
# TorchModel(
#   (predictor): bi_GRU_zero(
#     (GRU): GRU(43, 250, num_layers=3, batch_first=True, bidirectional=True)
#     (linear_out_y): Linear(in_features=500, out_features=12, bias=True)
#   )
#   (encoder): bi_GRU_init(
#     (GRU): GRU(86, 250, num_layers=3, batch_first=True, bidirectional=True)
#     (linear_in): Linear(in_features=6, out_features=500, bias=True)
#     (linear_peek): Linear(in_features=6, out_features=43, bias=True)
#     (linear_out_z): Linear(in_features=500, out_features=200, bias=True)
#   )
#   (decoder): uni_GRU_init(
#     (GRU): GRU(86, 250, num_layers=3, batch_first=True)
#     (linear_in): Linear(in_features=106, out_features=250, bias=True)
#     (linear_peek): Linear(in_features=106, out_features=43, bias=True)
#     (linear_out_x): Linear(in_features=250, out_features=43, bias=True)
#   )
#   (softmax): Softmax(dim=-1)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# # Property Prediction Performance

# %%
scaled_tstY_hat = model.predict_routine(sample_data = data).detach().cpu().numpy()
tstY_hat = [scaler_Y[i].inverse_transform(scaled_tstY_hat[:,i:i+1]) for i in range(scaled_tstY_hat.shape[1])]
tstY_hat = np.concatenate(tstY_hat, axis=1)

dim_y = data['dim_y']
tstY = data['tstY']
tstMask = data['tstMask']
Y_names = data['Y_names']
for j in range(dim_y):
    idx = np.where( tstMask[:,j] == 1 )[0]
    print('Label Name:', Y_names[j])
    print([j, mean_absolute_error(tstY[idx,j], tstY_hat[idx,j])])
# Out:
# Label Name: EA
# [0, 0.1326845341430336]
# Label Name: IE
# [1, 0.1409745993432492]
# Label Name: LogVis
# [2, 0.12709771448069]
# Label Name: MolWt
# [3, 1.3718315230057891]
# Label Name: n_F
# [4, 0.012760020706849168]
# Label Name: n_O
# [5, 0.02006005412503683]

# %% [markdown]
# # Unconditional Generation

# %%
print('Unconditional')
for t in range(10):
    smi = model.sampling_unconditional()
    print([t, smi, get_property(smi)])
# Out:
# Unconditional
# [0, 'COC(=O)c1ncc(C(F)(F)F)cc1-c1ccc(F)c(F)c1F', [335.03809778400006, 3.971300000000001, 0.4735385576400655]]
# RDKit ERROR: [12:36:55] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 26 27
# [12:36:55] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 26 27
#
# RDKit ERROR:
# [1, 'COc1cccc2cc(C(=O)N3CCN(c4ccccc4)CC3)c(=O)oc2c1', 'invalid']
# [2, 'Cn1c(C(F)(F)Cl)nc2c(Cl)cccc2c1=O', [277.98252461199996, 2.875000000000001, 0.7521948780070166]]
# [3, 'CN(Cc1cc(F)cc(F)c1)C(=O)C1CCCC1', [253.127820604, 3.113400000000002, 0.8101524203304447]]
# [4, 'NC(=O)c1c(C(F)(F)F)[nH]c2c(Cl)cccc2c1=O', [290.006989772, 2.2992, 0.8452828637797497]]
# [5, 'CCc1cc([N+](=O)[O-])cc(Br)c1O', [244.968755216, 2.6253000000000015, 0.6438949543829067]]
# [6, 'NC(c1cc(F)ccc1Br)c1ccc(F)c(C(F)(F)F)c1F', [382.974430676, 4.933300000000001, 0.7303953204838246]]
# [7, 'Cc1ccnc(N2CCN(c3cc(-c4ccc(Cl)cc4)no3)CC2)c1C#N', [379.119987876, 3.8967000000000027, 0.6870728426269869]]
# [8, 'FC(F)C(F)(F)C(F)(F)C(F)(Br)C', [275.93845976800003, 3.6027000000000005, 0.5458122040660648]]
# [9, 'CC(=O)c1cc(Br)c(OC(F)(F)F)cc1C=O', [309.94524081199995, 3.362800000000001, 0.6348645296825359]]

# %% [markdown]
# # Conditional Generation

# %%
print('Conditional')
# Determine the property values we want to use for conditional generation
ynames = ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O']
yids = [Y_names.index(yname) for yname in ynames]

for i1 in [0.5, 0.0]:
    for i2 in [7.0, 7.5]:
        for i3 in [0.0, -0.1]:
            for i4 in [250, 300]:
                for i5 in [4.0, 6.0]:
                    for i6 in [1.0, 2.0]:
                        ytargets = [i1,i2,i3,i4,i5,i6]
                        ymeans = np.array([scaler_Y[yid].mean_[0] for yid in yids])
                        ystds = np.array([np.sqrt(scaler_Y[yid].var_[0]) for yid in yids])
                        ytargets_transform = ( np.array(ytargets) - ymeans ) / ystds
                        
                        print(ynames, ':', ytargets)
                        for t in range(5):
                            smi = model.sampling_conditional(yids, ytargets_transform)
                            print([t, smi, get_property(smi)])
                        print('')
# Out:
# Conditional
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 1.0]
# [0, 'Cc1ccc(OCC(F)(F)C(F)(F)Cl)cc1', [256.027805468, 3.840720000000002, 0.5874324807507978]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 1.0]
# [1, 'Nc1c(F)cc(OC(F)(F)F)cc1CCl', [243.007404372, 3.045300000000001, 0.4922380929663293]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 1.0]
# [2, 'CC(C)C(=O)Nc1ccc(F)c(C(F)(F)F)c1', [249.077676852, 3.439000000000002, 0.7990657028483503]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 1.0]
# [3, 'CN(C)C(=O)Nc1c(F)c(F)cc(F)c1CF', [250.07292582, 2.666900000000001, 0.6348126724053753]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 1.0]
# [4, 'OCc1nc(C(F)(F)F)nc2c(F)cccc12', [246.041625692, 2.2800000000000002, 0.784972977193708]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 2.0]
# [0, 'CN(C)C(=O)OC1(C(F)(F)F)CCC(F)C1', [243.088241536, 2.5077000000000007, 0.6620880681603916]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 2.0]
# [1, 'CCOC(=O)c1cc(C(F)(F)F)nc(F)c1C', [251.056941408, 2.7246200000000007, 0.4605990025155386]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 2.0]
# [2, 'CC(=O)NCC(O)c1c(F)c(F)cc(F)c1F', [251.056941408, 1.4125000000000003, 0.6300521184427528]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 2.0]
# [3, 'OCc1c(OC(F)(F)F)ccc(F)c1C1CC1', [250.06169244, 3.094000000000001, 0.8351157739812953]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 4.0, 2.0]
# [4, 'COc1ccc(OCC(F)(F)C(F)F)c(C)c1', [252.077342504, 3.282820000000002, 0.7485445376553623]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 1.0]
# [0, 'Oc1nc(F)cc(CC(F)(F)C(F)(F)F)n1', [246.022782068, 2.0614, 0.6413237639490631]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 1.0]
# [1, 'FC(C(F)(F)F)C(F)(F)COC1CCCC1', [250.079234324, 3.481300000000002, 0.6939027734401653]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 1.0]
# [2, 'FC(F)(F)C(F)(F)COc1ccccc1F', [244.032284132, 3.402100000000001, 0.7401966094739406]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 1.0]
# [3, 'OC(CCC(F)(C(F)(F)F)C(F)F)C1CC1', [250.079234324, 3.0732000000000017, 0.7432899351192574]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 1.0]
# [4, 'Cn1nc(C(F)(F)F)c(C(F)(F)F)c1CO', [248.038432132, 1.9499999999999997, 0.771166337877078]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 2.0]
# [0, 'COC(=O)CCCC(F)(F)C(F)(F)C(F)F', [252.05849888, 2.865400000000001, 0.5363618416619229]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 2.0]
# [1, 'OC(O)c1cc(C(F)(F)F)c(F)c(F)c1F', [246.011548688, 2.105899999999999, 0.45229958298206746]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 2.0]
# RDKit ERROR: [12:38:17] SMILES Parse Error: extra close parentheses while parsing: Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1
# [12:38:17] SMILES Parse Error: extra close parentheses while parsing: Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1
# RDKit ERROR: [12:38:17] SMILES Parse Error: Failed parsing SMILES 'Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1' for input: 'Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1'
# [12:38:17] SMILES Parse Error: Failed parsing SMILES 'Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1' for input: 'Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1'
# [2, 'Cc1n(C(F)(F)F)C(=O)OC(F)(F)F)nn1', 'invalid']
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 2.0]
# [3, 'Oc1cc(C(F)(F)F)cc(C(F)(F)F)c1O', [246.011548688, 3.1354, 0.5449595566744846]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 250, 6.0, 2.0]
# [4, 'COC(=O)CCC(F)(C(F)(F)F)C(F)(F)F', [256.03342700400003, 2.772500000000001, 0.5729267498882376]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 1.0]
# [0, 'Cc1noc(-c2ccc(C(F)(F)F)cc2Cl)c1C(F)F', [311.013632624, 5.259820000000001, 0.7070251517911332]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 1.0]
# [1, 'Cc1cc(OC(F)(F)F)cc(F)c1I', [319.93212566, 3.6373200000000008, 0.5670448892947801]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 1.0]
# [2, 'COc1cnc(C(F)(F)F)c(F)c1CBr', [286.95688879200003, 3.1430000000000016, 0.6158228204465405]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 1.0]
# [3, 'Nc1c(F)cc(Oc2ccc(C(F)(F)F)cc2)c(Cl)c1', [305.023054436, 4.872400000000002, 0.6341928786629171]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 1.0]
# [4, 'COc1cnc(-c2ccc(C(F)(F)F)c(F)c2)c(Cl)c1', [305.023054436, 4.568500000000002, 0.7583393556166472]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 2.0]
# [0, 'OC(Cc1cc(F)c(Br)cc1F)C(F)(F)O', [301.956554444, 2.2158, 0.6638211056862302]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 2.0]
# [1, 'COC(=O)CCc1ccc(Cl)cc1C(F)(F)C(F)F', [298.038370152, 3.802500000000002, 0.6103026182815416]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 2.0]
# [2, 'CCOC(=O)Nc1c(C(F)(F)F)cc(F)nc1CCl', [300.028868088, 3.5467000000000013, 0.5274897656137961]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 2.0]
# [3, 'N[C@@H](Cc1cc(F)c(F)c(F)c1F)c1ccc(O)cc1O', [301.072591472, 2.8967000000000005, 0.46377664827419135]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 4.0, 2.0]
# [4, 'CCC(=O)NCC(=O)Nc1cc(C(F)(F)F)cc(F)c1C', [306.099140568, 2.6176200000000005, 0.8401799360338716]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 1.0]
# [0, 'COC(c1cc(C(F)(F)F)nc(C(F)(F)F)c1)C1CC1', [299.074483292, 4.216700000000002, 0.7797336077407008]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 1.0]
# [1, 'Nc1ccc(C(=O)NCC(F)(F)C(F)(F)C(F)F)cc1', [300.06973225999997, 2.534300000000001, 0.6483418219858937]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 1.0]
# [2, 'NCc1cc(OC(F)(F)F)c(Cl)cc1C(F)(F)F', [293.004210812, 3.716100000000001, 0.8436117610972071]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 1.0]
# [3, 'NC(=O)c1cc(C(F)(F)F)cc(C(F)(F)F)c1CCl', [305.004210812, 3.5619000000000005, 0.6586599550041149]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 1.0]
# [4, 'CC(C)C(=O)Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1', [299.074483292, 4.3187000000000015, 0.809632351862652]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 2.0]
# [0, 'OCc1ccc(C(F)(F)F)cc1OCCC(F)(F)CF', [302.074148944, 3.5714000000000024, 0.8140600595276423]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 2.0]
# [1, 'OB(O)c1c(C(F)(F)F)ccc(Cl)c1C(F)(F)F', [291.989706768, 2.0574, 0.6142647879412287]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 2.0]
# [2, 'COc1ccc(OC(C(F)(F)F)C(F)(F)C(F)F)nc1', [307.04432603600003, 3.300300000000002, 0.7822311340675551]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 2.0]
# [3, 'OCc1c(OC(F)(F)F)ncc(C(F)(F)F)c1C1CC1', [301.05374784800006, 3.3687000000000014, 0.8704285529946028]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, 0.0, 300, 6.0, 2.0]
# [4, 'CS(=O)(=O)Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1', [307.01016878400003, 3.095700000000001, 0.8534811441697436]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 1.0]
# [0, 'Oc1ccc(-c2ccc(F)c(F)c2)c(F)c1F', [242.035477692, 3.6156000000000006, 0.7570768681861559]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 1.0]
# [1, 'COC(c1c(F)c(F)nc(F)c1F)C1CCC1', [249.077676852, 3.1256000000000013, 0.6061699838282983]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 1.0]
# [2, 'NCc1cn(CC(F)(F)F)nc1CC(=O)F', [239.068174788, 0.9426999999999999, 0.6279975022867197]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 1.0]
# [3, 'NCc1cc(OC(F)(F)F)cc(Cl)c1F', [243.007404372, 2.8364000000000003, 0.8109361323421608]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 1.0]
# [4, 'Cn1cnc(OC(F)(F)F)c1-c1ccc(F)cc1', [260.057275756, 3.1248000000000014, 0.7755457621225955]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 2.0]
# [0, 'COc1cc(C(F)(F)F)nc(OC)c1CCF', [253.072591472, 2.629600000000001, 0.7728238370873233]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 2.0]
# [1, 'CC(O)c1c(OC(F)(F)F)cc(F)cc1CN', [253.072591472, 2.2363000000000004, 0.81206062697888]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 2.0]
# [2, 'OCCC(=O)Nc1ccc(F)c(C(F)(F)F)c1', [251.056941408, 2.1654, 0.808642107564409]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 2.0]
# [3, 'CC(N)(C(=O)O)c1nc(C(F)(F)F)ccc1F', [252.052190376, 1.4980000000000007, 0.7818035548567996]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 4.0, 2.0]
# [4, 'O=C(O)c1ccn(CCC(F)(F)C(F)F)c1F', [257.04751959600003, 2.615900000000001, 0.823676721321359]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 1.0]
# [0, 'OCc1nc(C(F)(F)F)c(C(F)(F)F)s1', [250.983954036, 2.673, 0.7782131619925201]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 1.0]
# [1, 'OCCc1c(F)c(F)c(C(F)(F)F)c(F)c1', [244.032284132, 2.6575000000000006, 0.6259722276463078]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 1.0]
# [2, 'C[C@@H](O)c1c(F)c(F)c(C(F)(F)F)c(F)c1', [244.032284132, 3.176, 0.5938191040774076]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 1.0]
# [3, 'OC(c1cc(F)cc(F)c1)C(F)(F)C(F)F', [244.032284132, 2.898600000000001, 0.8103279960429705]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 1.0]
# [4, 'CCc1c(OC(F)(F)F)n[nH]c1C(F)(F)F', [248.038432132, 2.889500000000001, 0.8169175462880567]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 2.0]
# [0, 'C=C(O)CC(=O)C(C(F)(F)F)C(F)(F)CF', [250.042848816, 2.800600000000001, 0.6013511406986104]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 2.0]
# [1, 'OC(F)(F)C(F)(F)Oc1ccc(F)c(F)c1', [246.011548688, 2.5215000000000005, 0.8301428676053706]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 2.0]
# [2, 'OC[C@@H](O)CCC(F)(F)C(F)(F)C(F)(F)F', [258.04907706800003, 1.9526999999999999, 0.7398283752208705]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 2.0]
# [3, 'OCCOCCC(F)(F)C(F)(F)C(F)(F)F', [258.04907706800003, 2.2183, 0.5843692614235705]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 250, 6.0, 2.0]
# [4, 'OCc1c(O)c(F)c(F)c(F)c1C(F)(F)F', [246.011548688, 2.3206, 0.58931389262519]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 1.0]
# [0, 'O=C(Cn1nc(C(F)(F)F)cc1Cl)c1ccccc1F', [306.01830340400005, 3.577300000000001, 0.641558090056018]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 1.0]
# [1, 'CC1CCN(C(=O)Nc2cc(F)cc(C(F)(F)F)c2)CC1', [304.11987601199996, 4.1083000000000025, 0.7781087544657537]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 1.0]
# [2, 'OC(c1cc(F)cc(F)c1)c1ccc(C(F)(F)Cl)cc1', [304.027805468, 4.334600000000002, 0.6606352446313902]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 1.0]
# [3, 'OC(c1cc(F)cc(F)c1)c1cnc(C(F)(F)Cl)cc1', [305.023054436, 3.7296000000000014, 0.6921772883990633]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 1.0]
# [4, 'CCc1nc(-c2ccc(OC(F)(F)F)cc2)nc(C)c1F', [300.08857588399997, 4.052120000000002, 0.8020399484355889]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 2.0]
# [0, 'Cc1cc(OC(F)(F)C(F)(F)C(=O)NC2CC2)cs1', [297.044662472, 2.942020000000001, 0.848640870400071]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 2.0]
# [1, 'COC(=O)c1ncc(C(F)(F)F)c(F)c1Br', [300.936153348, 2.7886000000000006, 0.5913232360824531]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 2.0]
# [2, 'COC(=O)Cc1nc(C(F)(F)F)c(F)cc1CCl', [285.01796905599997, 2.6938000000000004, 0.4868533644293629]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 2.0]
# [3, 'CCOC(=O)Cc1cc(C(F)(F)F)cc(F)c1CCl', [298.038370152, 3.688900000000003, 0.48129932866808084]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 4.0, 2.0]
# [4, 'FC(F)(F)Oc1cc(OC(F)F)cc(Br)n1', [306.92673153600003, 3.3441, 0.6337623028186644]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 1.0]
# [0, 'FC(F)C(F)(F)Oc1cc(C(F)(F)F)cnc1CCl', [310.994789, 4.075900000000001, 0.6173709383350585]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 1.0]
# [1, 'OCc1c(C(F)(F)F)ccc(C(F)(F)F)c1CCl', [292.008961844, 3.955300000000001, 0.6461234357896984]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 1.0]
# [2, 'CCc1nc(OC(F)(F)F)c(C(F)(F)F)cc1CC#N', [298.054082196, 3.627480000000002, 0.8005023662742075]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 1.0]
# [3, 'OC(c1nc2ccccc2s1)C(F)(F)C(F)(F)CF', [297.024675976, 3.5698000000000008, 0.8751944334629828]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 1.0]
# [4, 'Fc1ccc(-c2ccc(OC(F)(F)F)cc2)c(F)c1F', [292.03228413200003, 4.6695, 0.5770913864534206]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 2.0]
# [0, 'Cc1c(OC(F)(F)F)cnc(C(F)(F)F)c1CC(N)=O', [302.048996816, 2.33522, 0.8715578285299139]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 2.0]
# [1, 'O=C(O)C(CC(F)(F)C(F)(F)C(F)F)c1ccccc1', [300.05849888, 3.7806000000000024, 0.8117790227986855]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 2.0]
# [2, 'OCc1cc(OC(F)(F)F)c(Cl)cc1C(F)(F)F', [293.98822640000003, 3.7497000000000007, 0.8418592670505478]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 2.0]
# [3, 'C[C@@](N)(C(=O)O)c1nc(C(F)(F)F)c(C(F)(F)F)n1C', [305.05989584800005, 1.7162000000000006, 0.815189044163523]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.0, -0.1, 300, 6.0, 2.0]
# [4, 'CCOC(=O)c1cc(C(F)(F)F)ccc1C(F)(F)CF', [300.05849888, 3.9434000000000022, 0.621591891763281]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 1.0]
# [0, 'Cc1ccc(CNC(=O)C(F)(F)C(F)F)cc1', [249.077676852, 2.5116200000000006, 0.8160484392295432]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 1.0]
# [1, 'Cc1cc(CC(=O)NCC(F)(F)F)ccc1F', [249.077676852, 2.3551200000000003, 0.8184554927722293]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 1.0]
# [2, 'O=C(c1cccnc1)c1cc(F)c(F)c(F)c1F', [255.03072666, 2.8690000000000007, 0.3572423208000622]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 1.0]
# [3, 'FC(F)(F)c1cccc(Oc2ccccc2)c1F', [256.051127756, 4.636800000000002, 0.7112194890912555]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 1.0]
# [4, 'CCNC(=O)Nc1ccc(F)c(C(F)(F)F)c1', [250.07292582, 2.985900000000001, 0.778209981997467]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 2.0]
# [0, 'OCCC(=O)Nc1c(F)cccc1C(F)(F)F', [251.056941408, 2.1654, 0.808642107564409]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 2.0]
# [1, 'O=C(Cc1ccc(OC(F)(F)F)cc1)C1CC1', [244.071114252, 3.1068000000000016, 0.8130072609436632]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 2.0]
# [2, 'CCOc1c(OC(F)(F)F)cc(F)cc1C#N', [249.041291344, 2.9946800000000016, 0.7730951586594075]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 2.0]
# [3, 'CCOC1(C(F)(F)F)Oc2ccc(F)cc2C1', [250.06169244, 3.0557000000000007, 0.7508928012638362]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 4.0, 2.0]
# [4, 'CC(C)CC(=O)NCC(O)CC(F)(F)C(F)F', [259.119541664, 1.8001, 0.6848601881159979]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 1.0]
# [0, 'O=C(NCC(F)(F)C(F)CF)CC(F)(F)F', [255.049411416, 1.9979, 0.7477844581864712]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 1.0]
# [1, 'Cc1cnc(OC(F)(F)F)c(C(F)(F)F)c1', [245.0275331, 3.3074200000000014, 0.7079078588518116]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 1.0]
# [2, 'O=C(Nc1cc(F)cc(F)c1F)C(F)(F)F', [243.011883036, 2.6047000000000002, 0.5957373000938051]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 1.0]
# [3, 'NCC(O)CCC(C(F)(F)F)C(F)(F)F', [239.074483292, 1.827, 0.7349603596346965]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 1.0]
# [4, 'Fc1cc(OCC(F)(F)F)ccc1C(F)F', [244.032284132, 3.7044000000000006, 0.7363230274443288]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 2.0]
# [0, 'O=C(O)CCCCC(F)(F)C(F)(F)C(F)F', [252.05849888, 3.1671000000000022, 0.5578011583767154]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 2.0]
# [1, 'CCOC(=O)CC(C(F)(F)F)C(F)(F)CF', [252.05849888, 2.722900000000001, 0.5551455028685739]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 2.0]
# [2, 'Fc1cccc(OC(F)(F)OC(F)(F)F)c1', [246.011548688, 3.291200000000001, 0.6014012223588888]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 2.0]
# [3, 'Oc1cc(OC(F)(F)F)cc(C(F)(F)F)c1', [246.011548688, 3.3096000000000005, 0.7700252910053019]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 250, 6.0, 2.0]
# [4, 'CCC(=O)OCC(C(F)(F)F)C(F)(F)CF', [252.05849888, 2.722900000000001, 0.5551455028685739]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 1.0]
# [0, 'O=C(NCC(F)(F)C(F)F)c1ccc(Cl)cc1Cl', [302.984082084, 3.6236000000000015, 0.8457415626212397]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 1.0]
# [1, 'CCc1ncc(OC(F)(F)F)c(F)c1CBr', [300.972538856, 3.5766000000000018, 0.6287721818153928]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 1.0]
# [2, 'FC(F)(F)c1ccc(Oc2ncccc2Cl)c(F)c1', [291.007404372, 4.685200000000001, 0.7492035771245448]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 1.0]
# [3, 'Nc1ncc(F)cc1C(=O)Nc1ccc(C(F)(F)F)cc1', [299.068174788, 3.0740000000000007, 0.8373640750811945]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 1.0]
# [4, 'CCCc1nc(OC(F)(F)F)nc(F)c1Br', [301.967787824, 3.229300000000001, 0.6350075996937237]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 2.0]
# [0, 'CC(Oc1cccc(C(F)(F)F)c1)C(=O)c1ccccc1', [294.08676431600003, 4.3556000000000035, 0.7833204968329469]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 2.0]
# [1, 'COCc1nc(OC(F)(F)F)c(F)cc1Br', [302.951803412, 3.028200000000001, 0.8044389212803034]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 2.0]
# [2, 'O=C(NCC(F)(F)CO)c1c(F)cc(F)cc1CCl', [299.03361911999997, 2.061, 0.6457477208672433]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 2.0]
# [3, 'FC(F)(F)Oc1cc(F)c(OCc2cccnc2)c(C)c1', [301.07259147200006, 4.006720000000002, 0.7996789266489753]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 4.0, 2.0]
# [4, 'CS(=O)(=O)Nc1ccc(C(F)(F)C(F)F)c(Cl)c1', [304.990040056, 3.0684000000000013, 0.8690400048169394]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 1.0]
# [0, 'Cc1c(C(F)(F)F)cc(OC(F)(F)F)nc1CCl', [293.004210812, 4.046220000000001, 0.6061404589434125]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 1.0]
# RDKit ERROR: [12:43:28] Can't kekulize mol.  Unkekulized atoms: 1 2 18
# [12:43:28] Can't kekulize mol.  Unkekulized atoms: 1 2 18
#
# RDKit ERROR:
# [1, 'Cc1cn(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)no1', 'invalid']
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 1.0]
# [2, 'Nc1cc(OC(F)(F)F)cc(C(F)(F)F)c1CCl', [293.004210812, 3.9250000000000007, 0.5093443143929853]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 1.0]
# [3, 'FC(F)(F)Oc1ccc(-c2ccc(C(F)(F)F)cc2)cc1', [306.047934196, 5.271000000000003, 0.6866747159445941]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 1.0]
# [4, 'O=Cc1ccc(C(F)(F)F)c(C(F)(F)F)c1CCl', [289.99331178, 4.275500000000001, 0.45135479469340883]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 2.0]
# [0, 'OCC(Oc1cccc(C(F)(F)F)c1)CC(F)(F)CF', [302.074148944, 3.440000000000002, 0.8157391651560885]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 2.0]
# [1, 'O=Cc1cc(OCC(F)(F)C(F)(F)C(F)F)ccc1N', [301.05374784800006, 2.995800000000001, 0.4990692145879178]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 2.0]
# [2, 'OCc1c(OC(F)(F)F)ncc(C(F)(F)F)c1Cl', [294.983475368, 3.1447000000000003, 0.8523781759566046]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 2.0]
# [3, 'NC(COCC(F)(F)F)c1cccc(OC(F)(F)F)c1', [303.06939791200006, 3.1639000000000017, 0.8498264939820944]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, 0.0, 300, 6.0, 2.0]
# [4, 'OCc1ccccc1OCCC(F)(F)C(F)(F)C(F)F', [302.074148944, 3.483500000000002, 0.7813895810440099]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 1.0]
# [0, 'CNCC(=O)Nc1cc(F)c(C(F)(F)F)cc1', [250.07292582, 2.0023999999999997, 0.8054901212741202]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 1.0]
# [1, 'OC(CC(F)(F)F)c1ccc(F)c(Cl)c1', [242.012155404, 3.464900000000001, 0.7876706618778582]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 1.0]
# [2, 'Fc1ccc(COc2ccccc2F)c(F)c1F', [256.051127756, 3.822000000000001, 0.5988230440887844]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 1.0]
# [3, 'OCc1cc(C(F)(F)F)c(F)cc1CCl', [242.012155404, 3.0756000000000006, 0.6242110973374227]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 1.0]
# [4, 'COc1c(C(F)(F)F)ccc(F)c1CCl', [242.012155404, 3.5919000000000016, 0.5688298999452409]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 2.0]
# [0, 'CN(C(=O)O)c1cc(C(F)(F)F)cc(F)c1C', [251.056941408, 3.267120000000002, 0.777980685587304]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 2.0]
# [1, 'CS(=O)(=O)CCSCC(F)(F)C(F)F', [254.00583444, 1.6646, 0.5338295422314634]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 2.0]
# [2, 'CCC(=O)NCC(=O)NCC(F)(F)C(F)F', [244.083490504, 0.5292, 0.6694552760786122]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 2.0]
# [3, 'CNC1CC(C(F)(F)C(F)(F)C(=O)O)CC1', [243.088241536, 1.7297, 0.739142235742173]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 4.0, 2.0]
# [4, 'COC(=O)Nc1cccc(C(F)(F)C(F)F)c1', [251.056941408, 3.2218000000000018, 0.8373978419138142]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 1.0]
# [0, 'C[C@H](O)c1cc(C(F)(F)F)cc(C(F)(F)F)c1', [258.047934196, 3.7775000000000007, 0.759883383475471]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 1.0]
# [1, 'OCC(F)(F)C(F)(F)c1cc(F)cc(F)c1', [244.032284132, 2.6842000000000015, 0.8102671625758164]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 1.0]
# RDKit ERROR: [12:44:34] Can't kekulize mol.  Unkekulized atoms: 2 3 4 9 10
# [12:44:34] Can't kekulize mol.  Unkekulized atoms: 2 3 4 9 10
#
# RDKit ERROR:
# [2, 'NCc1cc(C(F)(F)F)nc(C(F)(F)F)o1', 'invalid']
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 1.0]
# [3, 'C[C@H](N)CC(=O)NC(C(F)(F)F)C(F)(F)F', [252.06973226, 1.3331, 0.7444164054209939]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 1.0]
# [4, 'Cc1cc(OC(F)(F)F)nc(C(F)(F)F)c1', [245.0275331, 3.3074200000000005, 0.7079078588518117]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 2.0]
# [0, 'OCc1c(F)c(F)c(OC(F)(F)F)c(F)c1', [246.011548688, 2.4948000000000006, 0.6412837531178605]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 2.0]
# [1, 'C=CCOC(=O)CC(F)(F)C(F)(F)C(F)F', [250.042848816, 2.641400000000001, 0.4112523328045644]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 2.0]
# [2, 'OCc1cc(C(F)(F)F)cc(C(F)(F)F)c1O', [260.027198752, 2.922100000000001, 0.7619966870072578]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 2.0]
# [3, 'Cc1c(OC(F)(F)F)[nH]c(C(F)(F)F)c1O', [249.02244772, 2.94612, 0.7513383708701593]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 250, 6.0, 2.0]
# [4, 'C=CCOC(=O)C(C(F)(F)F)C(F)(F)CF', [250.042848816, 2.498900000000001, 0.42543789880599925]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 1.0]
# [0, 'OC(c1c(F)c(F)c(F)c(F)c1Br)C1CC1', [297.96163982400003, 3.448900000000001, 0.5036463191470797]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 1.0]
# [1, 'Oc1nc(F)c(C(F)(F)F)cc1I', [306.911724564, 2.5496999999999996, 0.4538545178480596]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 1.0]
# [2, 'OC(Cc1ccc(F)c(Br)c1)CC(F)(F)F', [299.97728988800003, 3.4440000000000017, 0.8479474087680281]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 1.0]
# [3, 'COc1nc(C(F)(F)F)ccc1CBr', [268.96631060400006, 3.0039000000000016, 0.770510593984525]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 1.0]
# [4, 'O=C(Cc1nc(C(F)(F)F)ns1)c1ccc(F)cc1C', [304.029346756, 3.429820000000001, 0.644289745638047]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 2.0]
# [0, 'CC(=O)Nc1nc(-c2ccc(C(F)(F)F)c(F)c2)c(C)o1', [302.06784043999994, 3.766320000000002, 0.8592024097823189]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 2.0]
# [1, 'Oc1cccc(Oc2c(F)c(F)c(F)c(F)c2Cl)c1C', [306.00707002400003, 4.702720000000001, 0.4947712159371629]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 2.0]
# RDKit ERROR: [12:45:23] Can't kekulize mol.  Unkekulized atoms: 8 9 10 11 16
# [12:45:23] Can't kekulize mol.  Unkekulized atoms: 8 9 10 11 16
#
# RDKit ERROR:
# [2, 'OCc1ccc(OCc2nnc(C(F)(F)F)n2)c(F)c1F', 'invalid']
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 2.0]
# [3, 'O=S(=O)(Cc1ccc(F)cc1)c1c(F)cc(F)cc1F', [304.018113376, 3.2169000000000016, 0.6443387279782008]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 4.0, 2.0]
# [4, 'OC(O)(c1c(F)cccc1F)c1cc(F)c(Cl)cc1F', [306.00707002400003, 3.0821000000000005, 0.5084124290368293]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 1.0]
# [0, 'OC(C(F)(F)C(F)(F)C(F)(F)F)C(Cl)(Cl)Cl', [315.905945264, 3.5504, 0.6098708811361466]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 1.0]
# [1, 'OCC(c1c(F)cc(F)cc1Cl)C(F)(F)C(F)(F)F', [309.99954003199997, 3.8917, 0.8397994768265501]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 1.0]
# [2, 'FC(F)(F)Oc1ccnc(-c2ccc(C(F)(F)F)cc2)c1', [307.043183164, 4.666000000000001, 0.7524524788537045]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 1.0]
# [3, 'CS(=O)c1cc(C(F)(F)F)cc(C(F)(F)F)c1C#N', [300.99960410000006, 3.333280000000001, 0.7465111984818441]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 1.0]
# [4, 'OC(F)(C(F)(F)F)C(F)(F)I', [293.897631972, 2.2346, 0.4465582047186384]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 2.0]
# [0, 'FC(F)(F)c1cc2c(cc1C(F)(F)F)OCCCCO2', [300.05849888, 4.275600000000002, 0.6659535382179902]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 2.0]
# [1, 'CCCC(=O)OCCCCC(F)(F)C(F)(F)C(F)(F)F', [312.09602726, 4.332900000000003, 0.37864285642824663]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 2.0]
# [2, 'COC(=O)Cc1cc(C(F)(F)F)cc(C(F)(F)F)c1C', [300.05849888, 3.748120000000002, 0.6140170955361769]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 2.0]
# [3, 'O=C(Cc1cc(C(F)(F)F)cc(C(F)(F)F)c1)C(N)=O', [299.03809778400006, 2.3211, 0.6875525706848058]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.5, 7.5, -0.1, 300, 6.0, 2.0]
# [4, 'CCc1cc(C(F)(F)F)cc(C(F)(F)F)c1CC(=O)O', [300.05849887999995, 3.9137000000000013, 0.8592355261197099]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 1.0]
# [0, 'CN(C)C(=O)Nc1cc(F)cc(C(F)(F)F)c1', [250.07292582, 2.9380000000000015, 0.7634355767039809]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 1.0]
# [1, 'CC(C)(C)OC(c1cc(F)cc(F)c1)C(F)F', [250.098077948, 4.086100000000003, 0.7341310155783852]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 1.0]
# [2, 'CCOC(=N)c1c(F)cccc1CC(F)(F)F', [249.077676852, 3.292370000000002, 0.49738994606180537]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 1.0]
# [3, 'Nc1cc(C(F)(F)F)ccc1OCCC(F)C', [251.093326916, 3.414500000000002, 0.657012916014655]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 1.0]
# [4, 'Fc1cc(OC(F)(F)F)cc(C2CCNC2)c1', [249.077676852, 2.8012000000000006, 0.8136312417250363]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 2.0]
# [0, 'Oc1cc(OC(F)(F)F)cc(F)c1CCl', [243.99141996, 3.1687000000000003, 0.6395736837181563]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 2.0]
# [1, 'OC(OCC(F)(F)C(F)F)c1ccsc1', [244.018113376, 2.6560000000000006, 0.6370048486140124]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 2.0]
# [2, 'COC(=O)CC(CC(F)(F)F)c1ccccc1', [246.086764316, 3.285700000000002, 0.761877653973216]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 2.0]
# [3, 'Cc1cc(OCC(F)(F)C(F)(F)CO)ccn1', [253.072591472, 2.0317199999999995, 0.8163048236353837]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 4.0, 2.0]
# [4, 'COC(=O)Cc1c(F)cnc(C(F)F)c1CF', [251.056941408, 2.3433, 0.6086928762122239]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 1.0]
# [0, 'CC(OC(F)(F)F)c1ccccc1C(F)(F)F', [258.047934196, 4.302800000000001, 0.7183114002441948]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 1.0]
# [1, 'Cc1ncc(OC(F)(F)F)nc1C(F)(F)F', [246.022782068, 2.702420000000001, 0.7143471748547412]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 1.0]
# [2, 'OC(CCC(F)(F)C(F)(F)C(F)F)C1CC1', [250.079234324, 3.0732000000000017, 0.718108273436003]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 1.0]
# [3, 'Fc1ccc(OCC(F)(F)F)cc1C(F)F', [244.032284132, 3.7044000000000006, 0.7363230274443286]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 1.0]
# [4, 'NC(c1ccoc1)C(C(F)(F)F)C(F)(F)F', [247.043183164, 3.020200000000001, 0.8156270894781968]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 2.0]
# [0, 'OC(O)(CCCC(F)(F)F)CC(F)(F)F', [240.05849888, 2.3522999999999996, 0.584560635817003]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 2.0]
# [1, 'CC(=O)NCC(O)(C(F)(F)F)C(F)(F)F', [239.038097784, 0.9782, 0.705452809552303]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 2.0]
# [2, 'CCOc1ccc(C(F)(F)F)c(C(F)(F)F)c1', [258.047934196, 4.122900000000001, 0.7247555376687708]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 2.0]
# [3, 'OC(OCC(F)(F)F)c1cccc(F)c1F', [242.036620564, 2.5346, 0.651520613178383]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 250, 6.0, 2.0]
# [4, 'Oc1c(OC(F)(F)F)cccc1C(F)(F)F', [246.011548688, 3.3095999999999997, 0.770025291005302]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 1.0]
# [0, 'Fc1cnc(OC(F)(F)F)c(I)c1', [306.911724564, 2.7239000000000004, 0.5877918527565468]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 1.0]
# [1, 'O=C(Nc1ncc(C(F)(F)F)cc1Cl)c1ccccc1', [300.027725216, 4.006100000000003, 0.9103680637929539]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 1.0]
# [2, 'Cn1cc(-c2noc(-c3cc(F)c(F)c(F)c3F)n2)s1', [303.00894566, 3.3600000000000003, 0.41407525346524165]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 1.0]
# [3, 'NC(=O)c1c(F)cccc1Nc1cc(C(F)(F)F)ccn1', [299.068174788, 3.0820000000000007, 0.8557877856869576]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 1.0]
# [4, 'OC(Cc1ccc(C(F)(F)F)c(F)c1)c1cccs1', [290.03884882, 4.182100000000002, 0.8406690851100054]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 2.0]
# [0, 'NC(=O)COc1ccccc1-c1c(F)c(F)cc(F)c1F', [299.05694140800006, 2.7741000000000007, 0.6969302532710193]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 2.0]
# [1, 'OC(O)(c1cc(F)c(F)c(F)c1)c1ccc(F)cc1Cl', [306.00707002400003, 3.0821000000000014, 0.5084124290368293]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 2.0]
# [2, 'NCc1cnc(OC(F)(F)F)nc1Oc1c(F)cccc1', [303.063089408, 2.7653000000000008, 0.8794601796634297]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 2.0]
# [3, 'COc1ccc(CNc2cc(F)c(F)c(F)c2F)cc1O', [301.072591472, 3.5693000000000015, 0.5151816171323019]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 4.0, 2.0]
# [4, 'FC(F)(F)Oc1cccc(Oc2cc(F)cc(Cl)c2)c1', [306.00707002400003, 5.170000000000002, 0.728299377108938]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 1.0]
# [0, 'COc1c(C(F)(F)F)ncc(C(F)(F)F)c1CCl', [293.004210812, 3.866600000000001, 0.6099015053076906]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 1.0]
# [1, 'OC(c1ccc(F)cc1)c1c(F)c(F)c(F)c(F)c1F', [292.03228413200003, 3.6029, 0.5091857475779087]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 1.0]
# [2, 'Nc1cc(C(F)(F)F)cc(OC(F)(F)F)c1CCl', [293.004210812, 3.9250000000000007, 0.5093443143929853]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 1.0]
# [3, 'FC(F)(F)c1cccc(-c2ccc(OC(F)(F)F)cc2)c1', [306.047934196, 5.271000000000002, 0.6866747159445943]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 1.0]
# [4, 'Nc1c(F)cccc1Oc1cc(F)c(F)c(C(F)(F)F)c1', [307.043183164, 4.497200000000001, 0.6548114608997616]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 2.0]
# [0, 'COc1cc(C(F)(F)F)c(C(F)(F)F)c(CC(N)=O)c1', [301.053747848, 2.7606, 0.8728103986365026]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 2.0]
# [1, 'Cc1cc(OC(F)(F)F)nc(OC(F)(F)F)c1CC#N', [300.03334675200006, 3.2533000000000003, 0.804030499129987]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 2.0]
# [2, 'Cc1ccc(COCC(F)(F)C(F)(F)C(F)F)cc1O', [302.074148944, 3.752920000000002, 0.81093828516173]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 2.0]
# [3, 'O=C(O)Cc1cc(C(F)(F)F)nc(C(F)(F)F)c1CN', [302.04899681600006, 2.205, 0.8393184132525523]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, 0.0, 300, 6.0, 2.0]
# [4, 'OC(c1cccc(OC(F)(F)F)c1)c1ccc(F)cc1F', [304.05227062800003, 3.945100000000002, 0.870227271604393]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 1.0]
# [0, 'Cc1nc(-c2cccc(C(F)(F)F)c2F)c(C)o1', [259.062026788, 4.116340000000002, 0.7199306004610507]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 1.0]
# [1, 'CC(NC(=O)C(F)(F)C(F)F)c1ccccc1', [249.077676852, 2.7642000000000007, 0.8166302053759003]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 1.0]
# [2, 'CC(CO)Nc1ccccc1C(F)(F)C(F)F', [251.093326916, 2.8362000000000007, 0.7885684319575882]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 1.0]
# [3, 'CC(C)Oc1nc(C(F)(F)F)c(F)cc1CN', [252.088575884, 2.4853999999999994, 0.8405727103373734]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 1.0]
# [4, 'OCC1Cc2cc(C(F)(F)F)cc(F)c2S1', [252.023198756, 2.853600000000001, 0.7754543797351094]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 2.0]
# [0, 'OCC(O)Cc1ncc(C(F)(F)F)cc1CF', [253.072591472, 1.4656000000000002, 0.7987333767593642]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 2.0]
# [1, 'O=C(O)CC(CC(F)(F)C(F)F)c1ccc[nH]1', [253.072591472, 2.863500000000001, 0.765727148424336]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 2.0]
# [2, 'CCC(NCC(F)(F)C(F)F)C(=O)OCC', [245.1038916, 1.8180999999999998, 0.548915288562306]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 2.0]
# [3, 'COc1ccc2c(F)c(F)c(F)c(F)c2c1O', [246.030392312, 3.1104000000000007, 0.4756179689690573]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 4.0, 2.0]
# [4, 'NCc1cc(OC(F)(F)F)c(O)c(CF)c1C', [253.072591472, 2.52742, 0.8136762546019405]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 1.0]
# [0, 'N[C@@H](CO)c1c(F)c(F)c(F)c(F)c1CF', [241.052604976, 1.7046000000000001, 0.48040424211226357]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 1.0]
# [1, 'CCc1ccc(OC(F)(F)F)c(C(F)(F)F)c1', [258.047934196, 4.166400000000002, 0.7233320287796708]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 1.0]
# [2, 'Nc1cnc(OC(F)(F)F)c(C(F)(F)F)c1', [246.022782068, 2.581200000000001, 0.7744633062392644]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 1.0]
# [3, 'OC[C@@H](c1cc(F)c(F)c(F)c1)C(F)(F)F', [244.032284132, 2.7421000000000006, 0.6260702041310433]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 1.0]
# [4, 'COc1ncc(C(F)(F)F)c(C(F)(F)F)n1', [246.022782068, 2.522800000000001, 0.7139337616990099]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 2.0]
# [0, 'C[Si](C)(O)OC(F)(F)C(F)(F)C(F)(F)F', [260.01035353400005, 2.487500000000001, 0.6236852210702423]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 2.0]
# [1, 'COCC(O)CN(C(F)(F)F)C(F)(F)F', [241.053747848, 1.3353000000000002, 0.5950777963521485]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 2.0]
# [2, 'CCOC(C)C(O)(C(F)(F)F)C(F)(F)CF', [254.074148944, 2.3096000000000005, 0.7627317309202272]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 2.0]
# [3, 'O=C(O)CCCC(F)(F)C(F)CC(F)(F)F', [252.05849888, 3.1671000000000022, 0.7370057612126996]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 250, 6.0, 2.0]
# RDKit ERROR: [12:49:09] Explicit valence for atom # 11 C, 5, is greater than permitted
# [12:49:09] Explicit valence for atom # 11 C, 5, is greater than permitted
# [4, 'OC(O)(c1ccc(F)cc1F)C(F)(F)(F)F', 'invalid']
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 1.0]
# [0, 'Cc1ccc(CC(=O)Nc2cc(F)cc(F)c2)c(F)c1F', [297.077676852, 3.7326200000000016, 0.8592905532581026]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 1.0]
# [1, 'Cc1cc(C(F)(F)F)nc(Oc2cc(F)cc(Cl)c2)n1', [306.01830340400005, 4.388620000000001, 0.77190317119358]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 1.0]
# [2, 'CCCc1ncc(C(F)(F)F)c(Oc2ccc(F)cc2)n1', [300.088575884, 4.379300000000002, 0.7859681173757983]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 1.0]
# [3, 'CC(OCC(F)(F)C(F)F)c1ccc(Cl)cc1Cl', [304.00448317999997, 4.971400000000003, 0.697763629651831]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 1.0]
# [4, 'N#Cc1ccc(OCC(F)(F)C(F)F)cc1Br', [310.95688879200003, 3.5999800000000013, 0.7959543160877326]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 2.0]
# [0, 'NC(=O)COc1ccc(C(F)(F)F)c(F)c1Br', [314.951803412, 2.4711000000000007, 0.8711621791190433]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 2.0]
# [1, 'COC(=O)c1ccc(C(F)(F)F)c(-c2ccc(F)cc2)c1', [298.06169244, 4.2981000000000025, 0.6101781959933202]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 2.0]
# [2, 'FC(F)(F)Oc1ccc(OCc2ccncc2)c(F)c1C', [301.07259147200006, 4.006720000000001, 0.7996789266489754]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 2.0]
# [3, 'CCOc1cc(OC(F)(F)F)c(F)cc1Br', [301.956554444, 3.8855000000000013, 0.7888525018722803]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 4.0, 2.0]
# [4, 'N[C@@H](CC(=O)O)c1c(C(F)(F)F)cc(F)cc1CCl', [299.03361911999997, 3.057800000000001, 0.6632451820072413]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 1.0]
# [0, 'Nc1ccc(OCC(F)(F)C(F)(F)C(F)F)cc1C#N', [298.054082196, 3.0549800000000014, 0.6711083450759242]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 1.0]
# [1, 'Oc1cc(F)c(-c2ccc(C(F)(F)F)cc2)c(F)c1F', [292.03228413200003, 4.495300000000001, 0.6060084255084073]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 1.0]
# [2, 'CCN(CC(F)(F)C(F)(F)C(F)(F)F)C(=O)NC1CC1', [310.09161057600005, 3.013200000000001, 0.7779512945192962]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 1.0]
# [3, 'Fc1ccc(C(F)(F)F)c(Oc2cccc(F)c2)c1F', [292.03228413200003, 4.915000000000002, 0.7141591825063344]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 1.0]
# [4, 'Fc1cc(OC(F)(F)F)ccc1-c1ccc(F)c(F)c1', [292.03228413200003, 4.669500000000001, 0.7308402051099989]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 2.0]
# [0, 'Oc1ccc(COCC(F)(F)C(F)(F)C(F)F)cc1F', [306.04907706800003, 3.5836000000000015, 0.8140365451513727]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 2.0]
# [1, 'OC(O)(Cc1ccc(C(F)(F)F)cc1)CC(F)(F)CF', [302.074148944, 2.923700000000001, 0.6483726469993196]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 2.0]
# [2, 'OC(O)(c1cc(C(F)(F)F)cc(C(F)(F)F)c1)C1CC1', [300.05849888, 3.271600000000001, 0.6498640262029898]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 2.0]
# [3, 'O=C(NCC(F)(F)C(F)(F)C(F)F)c1ccc(O)cc1', [301.053747848, 2.6577, 0.8215063716142302]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.0, -0.1, 300, 6.0, 2.0]
# [4, 'FC(F)(F)COCCOc1c(F)cc(C(F)F)cc1N', [303.06939791200006, 3.3032000000000012, 0.49802987325153947]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 1.0]
# [0, 'Cc1c(OC(F)(F)F)cc(F)cc1CCl', [242.012155404, 3.7715200000000015, 0.566594699206567]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 1.0]
# [1, 'OC(CC(F)(F)F)c1ccc(F)c(Cl)c1', [242.012155404, 3.464900000000001, 0.7876706618778582]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 1.0]
# [2, 'COc1cc(C(F)(F)F)c(F)cc1CCl', [242.012155404, 3.5919000000000016, 0.5688298999452409]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 1.0]
# [3, 'OCc1cnc(C(F)F)c(Cl)c1C(F)(F)F', [260.99798256, 3.183700000000001, 0.829615934355459]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 1.0]
# [4, 'Nc1cc(OCC(F)(F)C(F)F)ccc1C#N', [248.057275756, 2.4196800000000005, 0.6571281431038007]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 2.0]
# [0, 'OCc1cc(OCCC(F)(F)F)cc(F)c1C', [252.077342504, 2.9576200000000012, 0.834656023536566]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 2.0]
# [1, 'OCc1c(C(F)F)ncc(OC(F)F)c1CC', [253.072591472, 2.675300000000001, 0.8201637302859319]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 2.0]
# [2, 'COc1nc(OC(F)(F)F)c(F)cc1CC#N', [250.036540312, 2.19398, 0.7714153635871838]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 2.0]
# [3, 'Cc1ccc(C(F)(F)C(F)(F)C(=O)O)cc1C', [250.06169244, 3.115140000000001, 0.8366861528130952]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 4.0, 2.0]
# [4, 'Cc1nc(C(F)(F)F)c(CC(=O)O)cc1CF', [251.056941408, 2.50542, 0.8395123084685875]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 1.0]
# [0, 'OC(c1cc(F)c(F)c(F)c1)CC(F)(F)F', [244.032284132, 3.0897000000000006, 0.625673005041945]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 1.0]
# [1, 'FCOc1cc(C(F)(F)F)ccc1C(F)(F)F', [262.02286232000006, 4.030000000000001, 0.7309564954351934]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 1.0]
# [2, 'Cc1ncc(C(F)(F)F)c(OC(F)(F)F)n1', [246.022782068, 2.70242, 0.7143471748547411]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 1.0]
# [3, 'OC(c1c(F)c(F)c(F)c(F)c1F)C(F)F', [248.007212256, 2.6806, 0.4843356047646283]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 1.0]
# [4, 'OCCc1c(F)c(F)c(C(F)(F)F)c(F)c1', [244.032284132, 2.6575000000000006, 0.6259722276463078]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 2.0]
# [0, 'FC(F)(F)C1(C(F)(F)F)OCCCCOC1', [252.05849888, 2.6768, 0.6169424230972382]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 2.0]
# [1, 'COC(=O)CCC(C(F)(F)F)C(F)(F)CF', [252.05849888, 2.722900000000001, 0.5551455028685739]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 2.0]
# [2, 'Cc1c(O)cc(C(F)(F)F)cc1OC(F)(F)F', [260.027198752, 3.6180199999999996, 0.7812618959066441]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 2.0]
# [3, 'O=C(OCCCCC(F)(F)F)CC(F)(F)F', [252.05849888, 3.2146000000000017, 0.4263486061201161]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 250, 6.0, 2.0]
# [4, 'CC(O)CCC(O)(C(F)(F)F)C(F)(F)F', [240.05849888, 2.0031000000000003, 0.7405497039391139]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 1.0]
# [0, 'CN(C)c1cc(C(F)(F)F)nc(Oc2ccc(F)cc2)n1', [301.083824852, 3.4928000000000017, 0.8134104308572903]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 1.0]
# [1, 'OC(c1cccc(C(F)(F)F)c1)c1c(F)cccc1Cl', [304.02780546800005, 4.579600000000002, 0.8052343337736231]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 1.0]
# [2, 'Cc1cnc(C(F)(F)F)c(Oc2ccc(F)c(Cl)c2)n1', [306.01830340400005, 4.388620000000002, 0.77190317119358]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 1.0]
# [3, 'N#Cc1ccc(COc2ccccc2C(F)(F)F)c(F)c1', [295.062026788, 4.295180000000002, 0.7910846391023437]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 1.0]
# [4, 'CNc1ccc(Oc2ccc(C(F)(F)F)nc2)c(F)c1C', [300.08857588399997, 4.381920000000002, 0.8540418389332283]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 2.0]
# [0, 'CS(=O)(=O)N1CCN(c2c(F)c(F)cc(F)c2F)C1', [298.03991144, 1.2821, 0.6099289262252025]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 2.0]
# [1, 'Oc1cc(OC(F)(F)F)ccc1CBr', [269.950326192, 3.1857000000000006, 0.8368609413835867]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 2.0]
# [2, 'CS(=O)(=O)Nc1ccc(SC(F)(F)C(F)F)cc1', [303.001083408, 3.0081000000000007, 0.6716557618487271]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 2.0]
# [3, 'O=S(=O)(c1cccc(C(F)(F)F)c1)c1ccc(F)cc1', [304.018113376, 3.6773000000000016, 0.6263477332041162]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 4.0, 2.0]
# [4, 'CC(Nc1cc(C(F)(F)F)cc(F)c1)C(=O)OC(C)(C)C', [307.11954166400005, 3.986600000000003, 0.6776930006683702]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 1.0]
# [0, 'Oc1c(F)cccc1-c1cc(C(F)(F)F)cc(F)c1F', [292.03228413200003, 4.4953, 0.7674613282981306]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 1.0]
# [1, 'OC(c1cccc(C(F)(F)F)c1)c1cccc(F)c1F', [288.05735600800006, 4.0653000000000015, 0.8260156533554464]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 1.0]
# [2, 'CC(=O)Nc1c(C(F)(F)F)cnc(C(F)(F)F)c1CN', [301.064981228, 2.5362999999999998, 0.8248504487006982]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 1.0]
# [3, 'OCc1cc(C(F)(F)F)cc(C(F)(F)F)c1CCl', [292.008961844, 3.955300000000001, 0.6461234357896984]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 1.0]
# [4, 'OC(c1ccc(C(F)(F)F)nc1)c1c(F)cc(F)cc1F', [307.043183164, 3.599400000000001, 0.860043584511532]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 2.0]
# [0, 'C[C@@H](NC(=O)O)c1cc(C(F)(F)F)cc(C(F)(F)F)c1', [301.05374784800006, 4.052800000000001, 0.8095143527421214]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 2.0]
# [1, 'CCOC(=O)Cc1c(F)cc(C(F)(F)F)cc1C(F)F', [300.05849888, 3.8877000000000015, 0.6227102647489877]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 2.0]
# [2, 'NC(=O)c1c(OC(F)(F)F)cnc(C(F)(F)F)c1CN', [303.04424578400005, 1.5566, 0.8289138641010623]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 2.0]
# [3, 'O=C(NCC(F)(F)F)N1CCC(O)(C(F)(F)F)CC1', [294.080296944, 1.6475, 0.7225117398738816]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, 0.0, 300, 6.0, 2.0]
# [4, 'FC(F)(F)Oc1ccc(OC(F)(F)C(F)Cl)cc1', [293.98822640000003, 4.091200000000001, 0.6148983629753403]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 1.0]
# [0, 'OC(c1cc(F)cc(C(F)(F)F)c1)C1CCC1', [248.082427884, 3.6780000000000017, 0.7914258521512539]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 1.0]
# [1, 'OCCc1cc(C(F)(F)F)c(Cl)cc1F', [242.012155404, 3.032700000000001, 0.7906612103423992]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 1.0]
# [2, 'OCCc1nc(C(F)(F)F)c(F)cc1Cl', [243.007404372, 2.4277000000000006, 0.8095671133595316]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 1.0]
# [3, 'Nc1cnc(OCCCC(F)(F)F)c(F)c1F', [256.063504008, 2.6633000000000013, 0.6651051392664115]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 1.0]
# [4, 'Nc1ccc(OCCC(F)(F)C(F)F)c(C)c1', [251.093326916, 3.246520000000002, 0.6436604902179087]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 2.0]
# [0, 'CCCC(=O)OCCCCC(F)(F)C(F)(F)F', [262.09922082, 3.697600000000002, 0.39704966241637685]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 2.0]
# [1, 'O=Cc1cc(OCC(F)(F)C(F)F)cs1', [242.002463312, 2.839800000000001, 0.5858679568599652]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 2.0]
# [2, 'OC(COCC(F)(F)F)c1ccc(F)c(C)c1', [252.077342504, 2.7464200000000014, 0.8347743752314701]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 2.0]
# [3, 'CCCOC(=O)Nc1c(F)c(F)cc(F)c1F', [251.056941408, 3.201500000000001, 0.6613356190132452]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 4.0, 2.0]
# [4, 'CCOC(=O)Nc1nc(C(F)(F)F)ccc1F', [252.052190376, 2.807900000000001, 0.8231761646500436]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 1.0]
# [0, 'Cc1c(OC(F)(F)F)cccc1C(F)(F)F', [244.032284132, 3.912420000000001, 0.6802493176919898]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 1.0]
# [1, 'Nc1ncc(F)c(OC(F)(F)F)c1C(F)F', [246.022782068, 2.6391, 0.8157412518145003]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 1.0]
# [2, 'CNCC(=O)NCC(F)(F)C(F)(F)C(F)F', [252.06973226, 0.8576999999999996, 0.6882236523510731]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 1.0]
# [3, 'Fc1cc(F)c(OCCC(F)(F)F)c(F)c1', [244.032284132, 3.435100000000001, 0.7398785926759053]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 1.0]
# [4, 'FC(F)(F)CCOc1cc(F)c(F)c(F)c1', [244.032284132, 3.435100000000001, 0.5842283441293153]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 2.0]
# [0, 'COC(=O)CCC(C(F)(F)F)C(F)(F)CF', [252.05849888, 2.722900000000001, 0.5551455028685739]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 2.0]
# [1, 'CC(CC(F)(F)C(F)(F)C(F)F)CC(=O)O', [252.05849888, 3.0230000000000006, 0.7375573168067182]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 2.0]
# [2, 'CC(C)(CC(F)(F)C(F)(F)C(F)F)C(=O)O', [252.05849888, 3.0230000000000006, 0.7634209915628494]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 2.0]
# [3, 'Cc1ccc(OC(F)(F)F)c(OC(F)(F)F)c1', [260.027198752, 3.7922200000000004, 0.7529369250667285]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 250, 6.0, 2.0]
# [4, 'FCOc1c(C(F)(F)F)[nH]c(C(F)F)c1O', [249.02244772, 2.9825000000000004, 0.8085965243046846]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 1.0]
# [0, 'OC(c1cccc(C(F)(F)F)c1)c1ccc(F)cc1Cl', [304.02780546800005, 4.579600000000002, 0.8052343337736231]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 1.0]
# [1, 'CC1CC(c2ccc(C(F)(F)F)cc2)NC(=O)NC1F', [290.10422594799996, 3.3811000000000018, 0.6039512619866888]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 1.0]
# [2, 'CC(NC(=O)CC(F)(F)C(F)F)c1ccc(Cl)cc1', [297.054354564, 3.8077000000000023, 0.822827099527832]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 1.0]
# [3, 'COc1cc(Br)cc(CC(F)(F)C(F)F)c1', [299.97728988800003, 3.9006000000000016, 0.7664142525031119]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 1.0]
# [4, 'Cn1nc(C(F)(F)F)cc1C(=O)Nc1ccc(F)cc1C', [301.083824852, 3.138720000000001, 0.8662538312893514]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 2.0]
# [0, 'CC(Oc1cccc(C(F)(F)F)c1)c1cccc(F)c1O', [300.077342504, 4.690100000000003, 0.8332319016437896]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 2.0]
# [1, 'COc1nc(C(F)(F)F)ccc1OCc1ccc(F)cc1', [301.07259147200006, 3.8271000000000015, 0.8043470342380873]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 2.0]
# [2, 'OC(COCC(F)(F)C(F)F)Cc1ncccc1Cl', [301.04926918399997, 2.5554000000000006, 0.7871320711395807]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 2.0]
# [3, 'FC(F)C(F)(F)Oc1ccccc1COc1ccccc1', [300.077342504, 4.502300000000003, 0.7311500840466864]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 4.0, 2.0]
# [4, 'COC(=O)c1ncc(C(F)(F)F)cc1-c1ccc(F)cc1', [299.05694140800006, 3.693100000000002, 0.62683862348743]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 1.0]
# [0, 'OCC(c1ccc(C(F)(F)F)c(C(F)(F)F)c1)C1CC1', [298.079234324, 4.210100000000002, 0.8287863507679972]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 1.0]
# [1, 'FC(F)(F)Oc1cc(C(F)(F)F)c(Cl)cc1Cl', [297.93868936399997, 4.9108, 0.6693700753514628]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 1.0]
# RDKit ERROR: [12:54:06] Can't kekulize mol.  Unkekulized atoms: 2 3 8
# [12:54:06] Can't kekulize mol.  Unkekulized atoms: 2 3 8
#
# RDKit ERROR:
# [2, 'Cn1nc(C(F)(F)F)c(-c2ccc(C(F)(F)F)cc2)c1=O', 'invalid']
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 1.0]
# [3, 'Cc1ccc(OCC(F)(F)C(F)(F)C(F)(F)Cl)cc1', [306.024611908, 4.476020000000002, 0.5756619727305032]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 1.0]
# [4, 'Fc1cc(OC(F)(F)F)ccc1-c1cc(F)cc(F)c1', [292.03228413200003, 4.669500000000001, 0.7308402051099989]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 2.0]
# [0, 'OC(Cc1ccc(OC(F)(F)F)cc1)CC(F)(F)CF', [302.074148944, 3.483500000000002, 0.8152320560510349]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 2.0]
# [1, 'OCc1ccc(COCC(F)(F)C(F)(F)C(F)F)cc1', [302.074148944, 3.231200000000002, 0.7836399336441776]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 2.0]
# [2, 'Oc1cc(OC(F)(F)F)ccc1SCC(F)(F)F', [291.999269752, 3.9452000000000007, 0.6755165063047532]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 2.0]
# [3, 'NC(=O)Cc1cc(C(F)(F)F)nc(OC(F)(F)F)c1C', [302.048996816, 2.3352199999999996, 0.8715578285299139]]
# ['EA', 'IE', 'LogVis', 'MolWt', 'n_F', 'n_O'] : [0.0, 7.5, -0.1, 300, 6.0, 2.0]
# [4, 'OC(c1c(F)c(F)c(F)c(F)c1F)c1ccc(F)cc1O', [308.027198752, 3.308500000000001, 0.5075363314941456]]
